# %%
import tensorflow as tf
import numpy as np

# %matplotlib inline
np.random.seed(1)
tf.random.set_seed(2)



from tensorflow.keras.preprocessing import image_dataset_from_directory
import matplotlib.pyplot as plt
import os
import tensorflow.keras.layers as tfl

# %%
directory_1 = './train_images'
dataset = image_dataset_from_directory(directory_1)
dataset.class_names
# Out:
# Found 872 files belonging to 5 classes.
# ['distorted', 'good', 'not_clear', 'not_result', 'wrong_oreintation']

# %%
BATCH_SIZE = 16
pixes = 516
IMG_SIZE = (pixes, pixes)
directory = './train_images/wrong_oreintation'
test_dataset = image_dataset_from_directory(directory,labels=None)
# Out:
# Found 271 files belonging to 1 classes.

# %%
# model = tf.keras.models.load_model('classify_1.h5')

# %%
prediction = model.predict(test_dataset)
# Out:
# 9/9 [==============================] - 40s 3s/step

# %%
np.argmax(prediction,axis=-1)
# Out:
# array([4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 4, 4,
#        4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 4, 4, 4, 4, 4,
#        4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 4,
#        4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 4, 4,
#        4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#        4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#        4, 4, 4, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 4, 4, 4, 4, 4, 4,
#        4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#        4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#        4, 4, 4, 4, 4, 4, 4, 4, 1, 4, 4, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#        4, 4, 4, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#        4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#        4, 4, 4, 4, 4, 4, 4], dtype=int64)

# %%
test_dataset.file_paths
# Out:
# ['./train_images/good\\result_146464_1677574266_thumb.jpg',
#  './train_images/good\\result_177833_1677614446_thumb.jpg',
#  './train_images/good\\3a89d820-7a84-4cfb-bfed-2833edc3f3d3-1.jpg',
#  './train_images/good\\result_1678026019_thumb.jpg',
#  './train_images/good\\result_255167_1677603523_thumb.jpg',
#  './train_images/good\\result_170459_1677569208_thumb.jpg',
#  './train_images/good\\result_177883_1677676678_thumb.jpg',
#  './train_images/good\\result_146634_1677613374_thumb.jpg',
#  './train_images/good\\result_146460_1677573843_thumb.jpg',
#  './train_images/good\\result_146653_1677584582_thumb.jpg',
#  './train_images/good\\result_146516_1677756278_thumb.jpg',
#  './train_images/good\\result_170511_1677613714_thumb.jpg',
#  './train_images/good\\result_146544_1677576699_thumb.jpg',
#  './train_images/good\\result_170504_1677538287_thumb.jpg',
#  './train_images/good\\result_176956_1677641820_thumb.jpg',
#  './train_images/good\\result_176960_1677643020_thumb.jpg',
# ...
